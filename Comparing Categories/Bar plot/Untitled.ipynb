# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('dress_review.csv')
df.head()
# Out:
#    s.no  age   division_name department_name class_name  clothing_id  \
# 0     0   40         General         Bottoms      Jeans         1028
# 1     1   62  General Petite            Tops    Blouses          850
# 2     2   47  General Petite         Bottoms     Skirts          993
# 3     3   45  General Petite         Bottoms      Pants         1068
# 4     4   37       Initmates        Intimate       Swim           24
#
#                     title                                        review_text  \
# 0    Amazing fit and wash  Like other reviewers i was hesitant to spend t...
# 1      Lovely and unique!  As is true of a bunch of the fall clothing pho...
# 2                     Meh  I so wanted this skirt to work, love the desig...
# 3                     Wow  Love love this! i was hesitant to buy this at ...
# 4  Great for bigger busts  I absolutely love the retro look of this swims...
#
#    alike_feedback_count  rating  recommend_index
# ...

# %% [markdown]
# ## Removing unnecessary features

# %%
df = df.drop(['s.no', 'clothing_id'], axis=1)
df.head()
# Out:
#    age   division_name department_name class_name                   title  \
# 0   40         General         Bottoms      Jeans    Amazing fit and wash
# 1   62  General Petite            Tops    Blouses      Lovely and unique!
# 2   47  General Petite         Bottoms     Skirts                     Meh
# 3   45  General Petite         Bottoms      Pants                     Wow
# 4   37       Initmates        Intimate       Swim  Great for bigger busts
#
#                                          review_text  alike_feedback_count  \
# 0  Like other reviewers i was hesitant to spend t...                     0
# 1  As is true of a bunch of the fall clothing pho...                    12
# 2  I so wanted this skirt to work, love the desig...                     3
# 3  Love love this! i was hesitant to buy this at ...                     0
# 4  I absolutely love the retro look of this swims...                     0
#
#    rating  recommend_index
# 0       5                 1
# ...

# %%
# Setting Fonts with Different Colors and Families
xfont = {
    'family': 'sans-serif',  # Change the font family to a sans-serif style
    'color': 'blue',         # Change the font color to blue
    'weight': 'normal',     # Use a normal font weight
    'size': 12,
}
yfont = {
    'family': 'sans-serif',
    'color': 'green',        # Change the font color to green
    'weight': 'normal',
    'size': 12,
}
title_font = {
    'family': 'monospace',   # Change the font family to a monospace style
    'color': 'red',          # Change the font color to red
    'weight': 'bold',       # Use a bold font weight
    'size': 14,
    'style': 'italic',      # Apply italic style
}
legend_prop = {
    'weight': 'normal',     # Use a normal font weight
    'size': 14,             # Increase the font size
    'style': 'oblique',     # Apply oblique style
}
highlight = {
    'family': 'cursive',     # Change the font family to a cursive style
    'color': 'darkorange',  # Change the font color to dark orange
    'weight': 'bold',
    'size': 14,             # Increase the font size
}

# %%
# Remove the trailing space from the column name
df.rename(columns={'recommend_index ': 'recommend_index'}, inplace=True)

# Grouping the data by 'rating' and 'recommend_index'
grouped = df.groupby(['rating', 'recommend_index']).size().unstack()

# Create the paired bar plot
ax=grouped.plot(kind='bar', stacked=True)

# Adding labels and title
plt.xlabel('Rating and Recommend Index')
plt.ylabel('Count')
plt.title('Paired Bar Plot: Rating vs. Recommend Index')
ax.set_xlabel('Products',fontdict=xfont)

ax.set_ylabel('Products Count', fontdict=yfont, labelpad=0, loc='center')

# Setting Title
ax.set_title('Top Rating Products Count', fontdict=title_font)

# Show the plot
plt.show()
